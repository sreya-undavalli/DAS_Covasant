# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("code/data/federer.csv")

# %%
df.head()
# Out:
#    year           tournament  start date type        surface      draw  \
# 0  1998   Basel, Switzerland  05.10.1998   WS   Indoor: Hard  Draw: 32
# 1  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 2  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 3  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 4  1998  Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay  Draw: 32
#
#   atp points  atp ranking tournament prize money round  ...  \
# 0          1        396.0                 $9,800   R32  ...
# 1         59        878.0                $10,800   R32  ...
# 2         59        878.0                $10,800   R16  ...
# 3         59        878.0                $10,800     Q  ...
# 4          1        680.0                   $520   R32  ...
#
#   player2 2nd serve return points total player2 break points converted won  \
# 0                                  22.0                                4.0
# ...

# %%
df
# Out:
#       year                  tournament  start date type        surface  \
# 0     1998          Basel, Switzerland  05.10.1998   WS   Indoor: Hard
# 1     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 2     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 3     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 4     1998         Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay
# ...    ...                         ...         ...  ...            ...
# 1174  2012  Australian Open, Australia  16.01.2012   GS  Outdoor: Hard
# 1175  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1176  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1177  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1178  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
#
#            draw atp points  atp ranking tournament prize money round  ...  \
# ...

# %%
df.shape
# Out:
# (1179, 70)

# %% [markdown]
# **Matches Won By Federer**

# %%
df['Double_faults']=df['player1 double faults']/df['player1 total points total']
Double_faults=df['Double_faults']
print(Double_faults)
# Out:
# 0       0.019417
# 1       0.000000
# 2       0.020270
# 3       0.046154
# 4            NaN
#           ...
# 1174    0.018116
# 1175    0.000000
# 1176    0.000000
# 1177    0.011561
# 1178         NaN
# Name: Double_faults, Length: 1179, dtype: float64

# %% [markdown]
# **Average Win**

# %%
Avg_wps=df[df['winner']=='Roger Federer'].groupby('surface').size()
print(Avg_wps)
# Out:
# surface
# Indoor: Carpet     56
# Indoor: Clay        5
# Indoor: Hard      189
# Outdoor: Clay     194
# Outdoor: Grass    122
# Outdoor: Hard     406
# dtype: int64

# %%
df.columns
# Out:
# Index(['year', 'tournament', 'start date', 'type', 'surface', 'draw',
#        'atp points', 'atp ranking', 'tournament prize money', 'round',
#        'opponent', 'ranking', 'score', 'stats link', 'tournament.1',
#        'tournament round', 'time', 'winner', 'player1 name',
#        'player1 nationality', 'player1 aces', 'player1 double faults',
#        'player1 1st serves in', 'player1 1st serves total',
#        'player1 1st serve points won', 'player1 1st serve points total',
#        'player1 2nd serve points won', 'player1 2nd serve points total',
#        'player1 break points won', 'player1 break points total',
#        'player1 service games played', 'player1 1st serve return points won',
#        'player1 1st serve return points total',
#        'player1 2nd serve return points won',
#        'player1 2nd serve return points total',
#        'player1 break points converted won',
#        'player1 break points converted total', 'player1 return games played',
# ...

# %%
# Create a new column for the proportion of double faults
df['double_faults_proportion'] = df['player1 double faults'] / df['player1 total points total']

# Display simple stats
print(df['double_faults_proportion'].describe())
# Out:
# count    1027.000000
# mean        0.012129
# std         0.010797
# min         0.000000
# 25%         0.004444
# 50%         0.010000
# 75%         0.018108
# max         0.060606
# Name: double_faults_proportion, dtype: float64

# %%
player = 'Roger Federer'
total_matches = len(df)
won_matches = df[df['winner'] == player].shape[0]

win_percentage = (won_matches / total_matches) * 100
print(f"{player} won {win_percentage:.2f}% of matches.")
# Out:
# Roger Federer won 82.44% of matches.

# %%
avg_wins_per_surface = df[df['winner'] == player].groupby('surface').size() / df.groupby('surface').size()
print(avg_wins_per_surface)
# Out:
# surface
# Indoor: Carpet    0.736842
# Indoor: Clay      0.833333
# Indoor: Hard      0.836283
# Outdoor: Clay     0.779116
# Outdoor: Grass    0.871429
# Outdoor: Hard     0.842324
# dtype: float64

# %%
df['start date'] = pd.to_datetime(df['start date'], errors='coerce')
df['year'] = df['start date'].dt.year

# Group by year and calculate average double fault proportion
avg_df_by_year = df.groupby('year')['double_faults_proportion'].mean()
print(avg_df_by_year)
# Out:
# year
# 1998.0    0.020738
# 1999.0    0.028285
# 2000.0    0.020918
# 2001.0    0.016780
# 2002.0    0.016084
# 2003.0    0.018211
# 2004.0    0.012856
# 2005.0    0.008778
# 2006.0    0.008495
# 2007.0    0.009116
# 2008.0    0.005306
# 2009.0    0.008313
# 2010.0    0.009711
# 2011.0    0.008275
# 2012.0    0.011024
# Name: double_faults_proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

avg_df_by_year.plot(kind='line', marker='o', title='Avg Double Fault Proportion by Year')
plt.xlabel('Year')
plt.ylabel('Avg Double Fault Proportion')
plt.grid(True)
plt.show()
