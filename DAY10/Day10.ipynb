# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bike = pd.read_csv(r"code/data/bikes.csv")

# %%
bike
# Out:
#            Date Unnamed: 1  Berri1   CSC  Mais1  Mais2  Parc  PierDup  \
# 0    01/01/2013      00:00       0     0      1      0     6        0
# 1    02/01/2013      00:00      69     0     13      0    18        0
# 2    03/01/2013      00:00      69     2     21      6    22        1
# 3    04/01/2013      00:00      80     0     22      4    16        0
# 4    05/01/2013      00:00      52     4     19      3    12        0
# ..          ...        ...     ...   ...    ...    ...   ...      ...
# 256  14/09/2013      00:00    2488  1494   1706   2911   979     1075
# 257  15/09/2013      00:00    2243  1749   1417   2933  1804     1459
# 258  16/09/2013      00:00    4206  2466   2799   5485  3272      855
# 259  17/09/2013      00:00    5506  3153   3563   6626  3882     1485
# 260  18/09/2013      00:00    1564  3330   1154   1803  4074     1759
#
#      Rachel1  Totem_Laurier
# 0          1              0
# 1          2              0
# 2          0              0
# ...

# %%
bike.head()
# Out:
#          Date Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# 0  01/01/2013      00:00       0    0      1      0     6        0        1
# 1  02/01/2013      00:00      69    0     13      0    18        0        2
# 2  03/01/2013      00:00      69    2     21      6    22        1        0
# 3  04/01/2013      00:00      80    0     22      4    16        0      125
# 4  05/01/2013      00:00      52    4     19      3    12        0       97
#
#    Totem_Laurier
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
bike.describe()
# Out:
#             Berri1          CSC        Mais1        Mais2         Parc  \
# count   261.000000   261.000000   261.000000   261.000000   261.000000
# mean   2743.390805  1221.858238  1757.590038  3224.130268  1669.425287
# std    2247.957848  1070.037364  1458.793882  2589.514354  1363.738862
# min       0.000000     0.000000     1.000000     0.000000     6.000000
# 25%     392.000000    12.000000   236.000000   516.000000   222.000000
# 50%    2771.000000  1184.000000  1706.000000  3178.000000  1584.000000
# 75%    4767.000000  2168.000000  3158.000000  5812.000000  3068.000000
# max    6803.000000  3330.000000  4716.000000  7684.000000  4103.000000
#
#            PierDup      Rachel1  Totem_Laurier
# count   261.000000   261.000000     261.000000
# mean   1152.885057  3084.425287    1858.793103
# std    1208.848429  2380.255540    1434.899574
# min       0.000000     0.000000       0.000000
# 25%      12.000000   451.000000     340.000000
# ...

# %%
bike['Date']=pd.to_datetime(bike['Date'], format='%d/%m/%Y')
plt.figure(figsize=(10,6))
plt.plot(bike['Date'],bike['Berri1'], label = 'Berri1')
plt.plot(bike['Date'],bike['PierDup'],label = 'PierDup')
plt.xlabel('Date')
plt.ylabel('Attendance')
plt.title('Daily Attendence of Berri1 & PierDup')
plt.show()

# %%
import datetime

# %%
bike['Date']= pd.to_datetime(bike['Date'], format="%d/%m/%Y")
bike['Weekday'] = bike['Date'].dt.day_name()

# %%
bike.Weekday
# Out:
# 0        Tuesday
# 1      Wednesday
# 2       Thursday
# 3         Friday
# 4       Saturday
#          ...
# 256     Saturday
# 257       Sunday
# 258       Monday
# 259      Tuesday
# 260    Wednesday
# Name: Weekday, Length: 261, dtype: object

# %%
bike.index
# Out:
# RangeIndex(start=0, stop=261, step=1)

# %%
bike
# Out:
#           Date Unnamed: 1  Berri1   CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# 0   2013-01-01      00:00       0     0      1      0     6        0        1
# 1   2013-01-02      00:00      69     0     13      0    18        0        2
# 2   2013-01-03      00:00      69     2     21      6    22        1        0
# 3   2013-01-04      00:00      80     0     22      4    16        0      125
# 4   2013-01-05      00:00      52     4     19      3    12        0       97
# ..         ...        ...     ...   ...    ...    ...   ...      ...      ...
# 256 2013-09-14      00:00    2488  1494   1706   2911   979     1075     3277
# 257 2013-09-15      00:00    2243  1749   1417   2933  1804     1459     3623
# 258 2013-09-16      00:00    4206  2466   2799   5485  3272      855     4307
# 259 2013-09-17      00:00    5506  3153   3563   6626  3882     1485     5332
# 260 2013-09-18      00:00    1564  3330   1154   1803  4074     1759     1511
#
# ...

# %%
bike.Weekday
# Out:
# 0        Tuesday
# 1      Wednesday
# 2       Thursday
# 3         Friday
# 4       Saturday
#          ...
# 256     Saturday
# 257       Sunday
# 258       Monday
# 259      Tuesday
# 260    Wednesday
# Name: Weekday, Length: 261, dtype: object

# %%
weekday_sum=bike.groupby('Weekday').sum(numeric_only=True)
print(weekday_sum)
# Out:
#            Berri1    CSC  Mais1   Mais2   Parc  PierDup  Rachel1  \
# Weekday
# Friday     105701  44252  71605  127526  64385    36850   118556
# Monday     106826  51646  68087  129982  69767    44500   119211
# Saturday    75754  27226  45947   79743  35544    46149    97143
# Sunday      74873  29181  40812   75746  37620    53812   100735
# Thursday   115193  52340  76273  141424  73668    36349   120684
# Tuesday    117244  54656  76974  141217  74299    40679   123533
# Wednesday  120434  59604  79033  145860  80437    42564   125173
#
#            Totem_Laurier
# Weekday
# Friday             71426
# Monday             72883
# Saturday           56438
# Sunday             53798
# Thursday           74540
# Tuesday            76559
# Wednesday          79501

# %%
weekday_sum.plot(kind = 'bar',figsize=(10,10))
plt.title('Sum of Attendance')
plt.xlabel('Weekday')
plt.ylabel('Total Attendance')
plt.show()
